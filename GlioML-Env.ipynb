# %%
# !pip3 install autogluon==0.8.0
# Out:
# ...
#   Using cached autogluon-0.8.0-py3-none-any.whl (9.7 kB)
# ...
#   Using cached autogluon.core-0.8.0-py3-none-any.whl (224 kB)
# ...
#   Using cached autogluon.features-0.8.0-py3-none-any.whl (61 kB)
# ...
#   Using cached autogluon.tabular-0.8.0-py3-none-any.whl (285 kB)
# ...
#   Using cached autogluon.multimodal-0.8.0-py3-none-any.whl (372 kB)
# ...
#   Using cached autogluon.timeseries-0.8.0-py3-none-any.whl (116 kB)
# ...
#   Using cached numpy-1.25.0-cp39-cp39-win_amd64.whl (15.1 MB)
# ...
#   Using cached scipy-1.11.1-cp39-cp39-win_amd64.whl (44.1 MB)
# ...
#   Using cached scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
# ...
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# ...
#   Using cached pandas-1.5.3-cp39-cp39-win_amd64.whl (10.9 MB)
# ...
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# ...
#   Using cached matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
# ...
#   Using cached boto3-1.27.0-py3-none-any.whl (135 kB)
# ...
#   Using cached autogluon.common-0.8.0-py3-none-any.whl (61 kB)
# ...

# %%
pip3 install autogluon==0.8.0
pip3 install seaborn==0.12.2
